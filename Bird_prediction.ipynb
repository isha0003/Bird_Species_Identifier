# %%
import pandas as pd
df_x=pd.read_csv("/Users/ishashree/Downloads/Dataset/training_set/training_set.csv")
df_x
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101
# 2     18.400000          NaN   200.000000    loc_3  3400.0  0.0  400
# 3     14.982114    47.504878          NaN      NaN  4800.0  0.0   98
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103
# ..          ...          ...          ...      ...     ...  ...  ...
# 430   17.000000    48.833824   196.000000      NaN  3500.0  1.0   45
# 431   17.100000          NaN   193.000000    loc_3  3400.0  0.0  398
# 432   19.400000          NaN          NaN    loc_1  3900.0  1.0  156
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  NaN   47
# 434   18.900000          NaN          NaN    loc_3  4300.0  1.0   92
#
# [435 rows x 7 columns]

# %%
df_y=pd.read_csv("/Users/ishashree/Downloads/Dataset/training_set/training_target.csv")
df_y
# Out:
#       ID species
# 0    284       C
# 1    101       C
# 2    400       B
# 3     98       C
# 4    103       C
# ..   ...     ...
# 430   45       B
# 431  398       A
# 432  156       A
# 433   47       B
# 434   92       A
#
# [435 rows x 2 columns]

# %%
df=pd.merge(df_x,df_y)
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000          NaN   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878          NaN      NaN  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000      NaN  3500.0  1.0   45       B
# 431   17.100000          NaN   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000          NaN          NaN    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  NaN   47       B
# 434   18.900000          NaN          NaN    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   bill_depth   434 non-null    float64
#  1   bill_length  295 non-null    float64
#  2   wing_length  298 non-null    float64
#  3   location     405 non-null    object
#  4   mass         433 non-null    float64
#  5   sex          379 non-null    float64
#  6   ID           435 non-null    int64
#  7   species      435 non-null    object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 30.6+ KB

# %%
df_0=df[df.species=="A"]
df_0
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 9          18.5          NaN        199.0    loc_3  4475.0  1.0  184       A
# 11         16.7    38.791391        178.0    loc_3  3250.0  0.0  212       A
# 14         19.0          NaN        199.0    loc_1  4000.0  1.0  479       A
# 15         16.9          NaN          NaN    loc_3  3000.0  0.0  510       A
# 16         21.5          NaN          NaN    loc_1  4200.0  1.0  424       A
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 425        17.5          NaN        190.0    loc_3  3900.0  1.0  112       A
# 429        19.0          NaN          NaN    loc_3  3425.0  1.0  452       A
# 431        17.1          NaN        193.0    loc_3  3400.0  0.0  398       A
# 432        19.4          NaN          NaN    loc_1  3900.0  1.0  156       A
# 434        18.9          NaN          NaN    loc_3  4300.0  1.0   92       A
#
# [160 rows x 8 columns]

# %%
df_1=df[df.species=="B"]
df_1
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 2          18.4          NaN        200.0    loc_3  3400.0  0.0  400       B
# 6          18.2          NaN        197.0    loc_3  3750.0  1.0   79       B
# 12         20.3    55.512336        194.0    loc_2  3775.0  NaN  195       B
# 19         17.8    46.400000        191.0    loc_3  3700.0  0.0  131       B
# 20         17.9    50.900000        196.0    loc_3  3675.0  0.0  343       B
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 418        17.9    55.512336        192.0      NaN  3500.0  1.0  244       B
# 422        19.0          NaN        200.0    loc_3  3800.0  1.0  113       B
# 423        18.6    49.700000        195.0    loc_3  3600.0  1.0  391       B
# 430        17.0    48.833824        196.0      NaN  3500.0  1.0   45       B
# 433        16.6    55.512336        187.0    loc_2  2900.0  NaN   47       B
#
# [93 rows x 8 columns]

# %%
df_2=df[df.species=="C"]
df_2
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 3     14.982114    47.504878          NaN      NaN  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# 5     15.000000    49.600000   216.000000    loc_2  4750.0  1.0  326       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 421   18.982114    38.259307          NaN      NaN  4300.0  0.0  135       C
# 424   14.800000    46.500000   217.000000    loc_2  5200.0  0.0   51       C
# 426   18.982114    47.504878          NaN    loc_2  5000.0  0.0  198       C
# 427   14.500000    46.500000   213.000000    loc_2  4400.0  0.0  367       C
# 428   14.000000    47.500000   212.000000    loc_2  4875.0  0.0  157       C
#
# [182 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df_0["bill_depth"],df_0["bill_length"],marker='+',color="blue")
plt.scatter(df_1["bill_depth"],df_1["bill_length"],color="green")
plt.scatter(df_2["bill_depth"],df_2["bill_length"],marker='*',color="red")

# %%
import seaborn as sn
sn.countplot(x="location",data=df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='location', ylabel='count'>

# %%
sn.countplot(x="sex",data=df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df.sex.value_counts(dropna=False)
# Out:
# 1.0    195
# 0.0    184
# NaN     56
# Name: sex, dtype: int64

# %%
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000          NaN   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878          NaN      NaN  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000      NaN  3500.0  1.0   45       B
# 431   17.100000          NaN   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000          NaN          NaN    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  NaN   47       B
# 434   18.900000          NaN          NaN    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df.sex.mode()
# Out:
# 0    1.0
# Name: sex, dtype: float64

# %%
df.location.mode()
# Out:
# 0    loc_2
# Name: location, dtype: object

# %%
df.sex=df["sex"].fillna(1)
df.location=df["location"].fillna("loc_2")
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000          NaN   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878          NaN    loc_2  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000    loc_2  3500.0  1.0   45       B
# 431   17.100000          NaN   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000          NaN          NaN    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  1.0   47       B
# 434   18.900000          NaN          NaN    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df["wing_length"].mean()
# Out:
# 202.7593987013696

# %%
df["wing_length"]=df["wing_length"].fillna(202.7593987013696)

# %%
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000          NaN   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878   202.759399    loc_2  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000    loc_2  3500.0  1.0   45       B
# 431   17.100000          NaN   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000          NaN   202.759399    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  1.0   47       B
# 434   18.900000          NaN   202.759399    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df["bill_length"].mean()
# Out:
# 46.1682206635505

# %%
df["bill_length"]=df["bill_length"].fillna(46.1682206635505)
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000    46.168221   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878   202.759399    loc_2  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000    loc_2  3500.0  1.0   45       B
# 431   17.100000    46.168221   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000    46.168221   202.759399    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  1.0   47       B
# 434   18.900000    46.168221   202.759399    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df["bill_depth"].isnull().values.sum()
# Out:
# 1

# %%
df["ID"].isnull().values.sum()
# Out:
# 0

# %%
df["bill_length"].isnull().values.sum()
# Out:
# 0

# %%
df["wing_length"].isnull().values.sum()
# Out:
# 0

# %%
df["mass"].isnull().values.sum()
# Out:
# 2

# %%
df["bill_depth"].mean()
# Out:
# 17.29555093477202

# %%
df.bill_depth=df["bill_depth"].fillna(17.29555093477202)

# %%
df.mass.mean()
# Out:
# 4290.877598152425

# %%
df.mass=df["mass"].fillna(4290.877598152425)
df
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284       C
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101       C
# 2     18.400000    46.168221   200.000000    loc_3  3400.0  0.0  400       B
# 3     14.982114    47.504878   202.759399    loc_2  4800.0  0.0   98       C
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103       C
# ..          ...          ...          ...      ...     ...  ...  ...     ...
# 430   17.000000    48.833824   196.000000    loc_2  3500.0  1.0   45       B
# 431   17.100000    46.168221   193.000000    loc_3  3400.0  0.0  398       A
# 432   19.400000    46.168221   202.759399    loc_1  3900.0  1.0  156       A
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  1.0   47       B
# 434   18.900000    46.168221   202.759399    loc_3  4300.0  1.0   92       A
#
# [435 rows x 8 columns]

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df_new=df.copy()

# %%
df_new["species"].replace(
{
    'A':0,
    'B':1,
    'C':2
},inplace=True)
df_new
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID  species
# 0     14.300000    48.200000   210.000000    loc_2  4600.0  0.0  284        2
# 1     14.400000    48.400000   203.000000    loc_2  4625.0  0.0  101        2
# 2     18.400000    46.168221   200.000000    loc_3  3400.0  0.0  400        1
# 3     14.982114    47.504878   202.759399    loc_2  4800.0  0.0   98        2
# 4     18.982114    38.259307   217.186992    loc_3  5200.0  0.0  103        2
# ..          ...          ...          ...      ...     ...  ...  ...      ...
# 430   17.000000    48.833824   196.000000    loc_2  3500.0  1.0   45        1
# 431   17.100000    46.168221   193.000000    loc_3  3400.0  0.0  398        0
# 432   19.400000    46.168221   202.759399    loc_1  3900.0  1.0  156        0
# 433   16.600000    55.512336   187.000000    loc_2  2900.0  1.0   47        1
# 434   18.900000    46.168221   202.759399    loc_3  4300.0  1.0   92        0
#
# [435 rows x 8 columns]

# %%
df_new["location"].replace(
{
    'loc_1':0,
    'loc_2':1,
    'loc_3':2
},inplace=True)
df_new
# Out:
#      bill_depth  bill_length  wing_length  location    mass  sex   ID  species
# 0     14.300000    48.200000   210.000000         1  4600.0  0.0  284        2
# 1     14.400000    48.400000   203.000000         1  4625.0  0.0  101        2
# 2     18.400000    46.168221   200.000000         2  3400.0  0.0  400        1
# 3     14.982114    47.504878   202.759399         1  4800.0  0.0   98        2
# 4     18.982114    38.259307   217.186992         2  5200.0  0.0  103        2
# ..          ...          ...          ...       ...     ...  ...  ...      ...
# 430   17.000000    48.833824   196.000000         1  3500.0  1.0   45        1
# 431   17.100000    46.168221   193.000000         2  3400.0  0.0  398        0
# 432   19.400000    46.168221   202.759399         0  3900.0  1.0  156        0
# 433   16.600000    55.512336   187.000000         1  2900.0  1.0   47        1
# 434   18.900000    46.168221   202.759399         2  4300.0  1.0   92        0
#
# [435 rows x 8 columns]

# %%
df.dtypes
# Out:
# bill_depth     float64
# bill_length    float64
# wing_length    float64
# location        object
# mass           float64
# sex            float64
# ID               int64
# species         object
# dtype: object

# %%
X=df_new.drop(["species","ID"],axis="columns")
X
# Out:
#      bill_depth  bill_length  wing_length  location    mass  sex
# 0     14.300000    48.200000   210.000000         1  4600.0  0.0
# 1     14.400000    48.400000   203.000000         1  4625.0  0.0
# 2     18.400000    46.168221   200.000000         2  3400.0  0.0
# 3     14.982114    47.504878   202.759399         1  4800.0  0.0
# 4     18.982114    38.259307   217.186992         2  5200.0  0.0
# ..          ...          ...          ...       ...     ...  ...
# 430   17.000000    48.833824   196.000000         1  3500.0  1.0
# 431   17.100000    46.168221   193.000000         2  3400.0  0.0
# 432   19.400000    46.168221   202.759399         0  3900.0  1.0
# 433   16.600000    55.512336   187.000000         1  2900.0  1.0
# 434   18.900000    46.168221   202.759399         2  4300.0  1.0
#
# [435 rows x 6 columns]

# %%
y=df_new.species
y
# Out:
# 0      C
# 1      C
# 2      B
# 3      C
# 4      C
#       ..
# 430    B
# 431    A
# 432    A
# 433    B
# 434    A
# Name: species, Length: 435, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_test,y_test)
# Out:
# 0.9540229885057471

# %%
y_pred=dtc.predict(X_test)

# %%
y_pred
# Out:
# array(['B', 'B', 'A', 'A', 'C', 'B', 'A', 'A', 'A', 'B', 'C', 'C', 'C',
#        'B', 'A', 'C', 'C', 'A', 'C', 'C', 'C', 'A', 'C', 'C', 'C', 'A',
#        'A', 'C', 'C', 'A', 'C', 'B', 'B', 'C', 'A', 'C', 'A', 'A', 'C',
#        'C', 'C', 'B', 'C', 'A', 'A', 'C', 'C', 'B', 'A', 'C', 'C', 'C',
#        'C', 'C', 'C', 'B', 'B', 'C', 'A', 'A', 'A', 'C', 'B', 'A', 'C',
#        'C', 'A', 'B', 'C', 'C', 'C', 'C', 'A', 'A', 'A', 'C', 'B', 'A',
#        'B', 'C', 'B', 'C', 'A', 'A', 'B', 'C', 'C'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
cf=confusion_matrix(y_test,y_pred)
cf
# Out:
# array([[28,  3,  0],
#        [ 0, 13,  0],
#        [ 0,  1, 42]])

# %%
sns.heatmap(cf,annot=True)
# Out:
# <AxesSubplot:>

# %%
test = pd.read_csv("/Users/ishashree/Downloads/Dataset/test_set/test_set.csv")

# %%
test
# Out:
#      bill_depth  bill_length  wing_length location    mass  sex   ID
# 0     14.982114    38.259307   217.186992    loc_2  5400.0  0.0    2
# 1     13.200000    46.100000   211.000000    loc_2  4500.0  0.0    5
# 2     20.000000          NaN   197.000000    loc_3  3300.0  1.0    7
# 3     17.500000    38.791391   190.000000    loc_3  3900.0  NaN    8
# 4     18.900000          NaN   184.000000    loc_2  3550.0  1.0    9
# ..          ...          ...          ...      ...     ...  ...  ...
# 104   19.000000          NaN          NaN    loc_1  3600.0  0.0  507
# 105   18.000000          NaN   210.000000    loc_1  4000.0  1.0  512
# 106   19.500000    49.000000   210.000000    loc_3  3950.0  1.0  516
# 107   17.900000    50.100000   190.000000    loc_3  3400.0  0.0  533
# 108   14.982114    38.259307          NaN    loc_3  5550.0  NaN  541
#
# [109 rows x 7 columns]

# %%
test["bill_depth"].mean()
# Out:
# 17.351317374284854

# %%
test["bill_depth"]=test["bill_depth"].fillna(17.351317374284854)

# %%
test["bill_length"].mean()
# Out:
# 46.02703650036888

# %%
test["bill_length"]=test["bill_length"].fillna(46.02703650036888)

# %%
test.sex.mode()
# Out:
# 0    0.0
# Name: sex, dtype: float64

# %%
test.sex=test.sex.fillna(0)

# %%
test.isnull().values.sum()
# Out:
# 45

# %%
test["wing_length"].mean()
# Out:
# 200.74029543112334

# %%
test["wing_length"]=test["wing_length"].fillna(200.74029543112334)

# %%
test.isnull().values.sum()
# Out:
# 7

# %%
test["mass"].isnull().values.sum()
# Out:
# 1

# %%
test["mass"].mean()
# Out:
# 4243.75

# %%
test["mass"]=test["mass"].fillna(4243.75)

# %%
test.location.mode()
# Out:
# 0    1.0
# Name: location, dtype: float64

# %%
test["mass"]=test["mass"].fillna("loc_2")

# %%
test
# Out:
#      bill_depth  bill_length  wing_length  location    mass  sex   ID
# 0     14.982114    38.259307   217.186992       1.0  5400.0  0.0    2
# 1     13.200000    46.100000   211.000000       1.0  4500.0  0.0    5
# 2     20.000000    46.027037   197.000000       2.0  3300.0  0.0    7
# 3     17.500000    38.791391   190.000000       2.0  3900.0  0.0    8
# 4     18.900000    46.027037   184.000000       1.0  3550.0  0.0    9
# ..          ...          ...          ...       ...     ...  ...  ...
# 104   19.000000    46.027037   200.740295       0.0  3600.0  0.0  507
# 105   18.000000    46.027037   210.000000       0.0  4000.0  0.0  512
# 106   19.500000    49.000000   210.000000       2.0  3950.0  0.0  516
# 107   17.900000    50.100000   190.000000       2.0  3400.0  0.0  533
# 108   14.982114    38.259307   200.740295       2.0  5550.0  0.0  541
#
# [109 rows x 7 columns]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
target_cols = "species"
num_cols = ["bill_depth", "bill_length", "wing_length", "mass"]
cat_cols = ["location", "sex"]
all_cols = num_cols + cat_cols + [target_cols]

le = LabelEncoder()

cat_imp = SimpleImputer(strategy="most_frequent")
num_imp = SimpleImputer(strategy="median")

test[cat_cols] = cat_imp.fit_transform(test[cat_cols])
test[num_cols] = num_imp.fit_transform(test[num_cols])

for col in cat_cols:
    if test[col].dtype == "object":
        test[col] = le.fit_transform(test[col])

for col in cat_cols:
    test[col] = pd.Categorical(test[col])
test_id = test["ID"]

all_cols.remove('species')
test = test[all_cols]

# %%
y_predict=dtc.predict(test)
# Out:
# /Users/ishashree/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
 submission_df = pd.concat([test_id, pd.DataFrame(y_predict, columns=['species'])], axis=1)
submission_df.head()
# Out:
#    ID species
# 0   2       C
# 1   5       C
# 2   7       A
# 3   8       A
# 4   9       B

# %%
submission_df.to_csv('solution.csv', index=False)
